# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/chris/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(len(int_words))
print(int_words[:50])
print(words[:50])
# Out:
# 16680599
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580, 0, 194, 10, 190, 58, 4, 5, 10712, 214, 6, 1324, 104, 454, 19, 58, 2731, 362, 6, 3672, 0]
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the']

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_count = Counter(int_words)
total_words = len(int_words)
threshold = 1e-5
freq = {word: word_count[word]/total_words for word in int_words}
prob = {word: 1 - np.sqrt(threshold/freq[word]) for word in int_words}
train_words = [word for word in int_words if prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    rand = random.randint(1,window_size + 1)
    if(idx - rand > 0):
        start = idx - rand
    else:
        start = 0
    
    stop = idx + rand
    
    return words[start:idx] + words[idx+1:stop+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32,shape=[None],name='inputs')
    labels = tf.placeholder(dtype=tf.int32,shape=[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/chris/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6183 0.3008 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6024 0.3000 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4619 0.2739 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5498 0.3395 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4525 0.3265 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5032 0.3055 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5199 0.2818 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4657 0.2822 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4196 0.2881 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3790 0.2830 sec/batch
# Nearest to or: evade, daisy, brightly, restarted, pyrenean, gleichschaltung, atm, branded,
# Nearest to th: valuing, neander, saturn, amen, culling, assimilated, deleuze, purport,
# Nearest to but: amerikkka, putting, antes, flocks, sacerdotal, sparrows, purely, headset,
# Nearest to their: transliteration, against, decoders, bonneville, validly, began, vigorous, huckleberries,
# Nearest to some: roth, carducci, stupidity, systems, rifts, lycanthropy, cruzi, directed,
# Nearest to two: synth, baby, orchard, atheist, quintuple, unlikely, counterfeit, incantation,
# Nearest to may: bbc, scan, eigenvalues, dingane, ambulances, firth, umlaut, schematic,
# Nearest to more: initials, rde, fascinating, decorative, menagerie, ced, skimmed, retrofit,
# Nearest to prince: hireling, letelier, meter, aiming, hellenism, aberrant, veiled, syllables,
# Nearest to ocean: anatomically, dragons, reprised, ironically, cities, asme, nobita, corral,
# Nearest to versions: coalition, chanced, mellish, enthusiasms, keep, alicia, disciplined, stylistic,
# Nearest to creation: provide, monies, suicides, outwardly, materialism, gab, faction, cypriot,
# Nearest to institute: percy, bletchley, chiefs, troubleshooting, frictions, downplayed, deutsche, brash,
# Nearest to nobel: joyce, dagda, caricom, feathers, maxis, limba, notional, clockless,
# Nearest to police: polynesia, free, milgrom, ditions, advice, horseman, radhakrishnan, potsdamer,
# Nearest to consists: amtrak, thema, challenges, staging, urals, mansi, stadion, starbuck,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4509 0.3052 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3525 0.3084 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3225 0.2865 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2290 0.2944 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1348 0.2883 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1566 0.2776 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0957 0.2738 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0688 0.2755 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0081 0.2763 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9991 0.2736 sec/batch
# Nearest to or: restarted, evade, d, pachomius, daisy, branded, brightly, company,
# Nearest to th: saturn, assimilated, be, amen, valuing, neander, purport, preclude,
# Nearest to but: putting, antes, purely, seen, sacerdotal, sparrows, experiment, flocks,
# Nearest to their: against, transliteration, began, validly, take, risk, bonneville, judge,
# Nearest to some: systems, roth, stupidity, directed, halt, collections, carducci, rifts,
# Nearest to two: synth, baby, yellow, unlikely, orchard, hazards, incantation, counterfeit,
# Nearest to may: bbc, scan, eigenvalues, schematic, firth, ambulances, due, produce,
# Nearest to more: initials, rde, nevertheless, skimmed, notable, fascinating, work, certain,
# Nearest to prince: hireling, aiming, meter, letelier, syllables, distribute, veiled, population,
# Nearest to ocean: anatomically, dragons, cities, ironically, reprised, nobita, corral, asme,
# Nearest to versions: keep, alicia, coalition, chanced, it, complements, ultimately, reported,
# Nearest to creation: provide, threats, faction, monies, suicides, materialism, outwardly, unity,
# Nearest to institute: percy, bletchley, deutsche, chiefs, london, oxidized, geology, danger,
# Nearest to nobel: joyce, feathers, dagda, caricom, exhibitions, orchard, maxis, notional,
# Nearest to police: free, polynesia, advice, milgrom, measures, ditions, rolling, residing,
# Nearest to consists: amtrak, challenges, urals, staging, communication, facing, starbuck, hydride,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9519 0.2754 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9026 0.2819 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8826 0.3063 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8592 0.3841 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8242 0.3383 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8466 0.3392 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8110 0.3358 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7824 0.3232 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7852 0.3891 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7831 0.3904 sec/batch
# Nearest to or: evade, daisy, restarted, brightly, branded, hooks, gleichschaltung, atm,
# Nearest to th: saturn, assimilated, valuing, purport, deleuze, laughs, amen, periods,
# Nearest to but: antes, putting, purely, amerikkka, flocks, sacerdotal, seen, elizabethan,
# Nearest to their: against, transliteration, themes, vigorous, fellows, swedish, validly, began,
# Nearest to some: systems, roth, stupidity, carducci, halt, irregular, collections, directed,
# Nearest to two: synth, hazards, baby, unlikely, five, counterfeit, georgia, orchard,
# Nearest to may: scan, bbc, schematic, ambulances, eigenvalues, cleverly, defect, umlaut,
# Nearest to more: initials, fascinating, rde, decorative, nevertheless, skimmed, work, municipal,
# Nearest to prince: hireling, aiming, veiled, distribute, appeal, letelier, hellenism, knights,
# Nearest to ocean: anatomically, dragons, ironically, cities, reprised, nobita, jesuits, asme,
# Nearest to versions: keep, coalition, chanced, stylistic, complements, it, barnabas, alicia,
# Nearest to creation: suicides, provide, outwardly, faction, imply, monies, threats, immense,
# Nearest to institute: percy, bletchley, deutsche, chiefs, danger, oxidized, geology, london,
# Nearest to nobel: joyce, feathers, exhibitions, orchard, caricom, miss, maxis, dagda,
# Nearest to police: polynesia, advice, free, milgrom, residing, measures, protest, ditions,
# Nearest to consists: amtrak, urals, challenges, facing, communication, staging, coupled, elves,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7599 0.3376 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7849 0.3169 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7185 0.3669 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7332 0.3287 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7721 0.3253 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6997 0.3313 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7150 0.3487 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7147 0.3006 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7070 0.3491 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6669 0.3495 sec/batch
# Nearest to or: evade, daisy, restarted, brightly, branded, atm, gleichschaltung, hooks,
# Nearest to th: assimilated, valuing, purport, saturn, laughs, lisan, deleuze, neander,
# Nearest to but: antes, putting, purely, amerikkka, flocks, trier, sacerdotal, weld,
# Nearest to their: fellows, vigorous, against, transliteration, racist, validly, themes, began,
# Nearest to some: systems, stupidity, roth, carducci, cruzi, damnation, halt, lycanthropy,
# Nearest to two: five, synth, zero, hazards, georgia, jesuit, four, counterfeit,
# Nearest to may: scan, defect, ambulances, schematic, eigenvalues, cleverly, bbc, dingane,
# Nearest to more: initials, fascinating, rde, skimmed, decorative, retrofit, work, miraculous,
# Nearest to prince: hireling, distribute, hellenism, knights, veiled, kinase, appeal, bacchus,
# Nearest to ocean: anatomically, cities, reprised, dragons, nobita, jesuits, rooting, hanging,
# Nearest to versions: keep, chanced, stylistic, disciplined, lingual, framing, coalition, barnabas,
# Nearest to creation: suicides, outwardly, provide, faction, imply, monies, mysql, ringen,
# Nearest to institute: percy, bletchley, chiefs, london, danger, tectonic, frictions, brash,
# Nearest to nobel: joyce, orchard, maxis, miss, exhibitions, caricom, dagda, max,
# Nearest to police: polynesia, free, advice, milgrom, ditions, residing, horseman, certificate,
# Nearest to consists: amtrak, urals, starbuck, challenges, elves, stalactites, coupled, facing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6549 0.3189 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6748 0.3197 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6203 0.3716 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6363 0.4239 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6334 0.3941 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6347 0.4398 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6158 0.3129 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5552 0.4068 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4981 0.3899 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5087 0.4065 sec/batch
# Nearest to or: daisy, evade, brightly, restarted, branded, atm, faroes, hooks,
# Nearest to th: assimilated, valuing, purport, lisan, neander, laughs, amen, saturn,
# Nearest to but: antes, amerikkka, elizabethan, putting, purely, weld, flocks, trier,
# Nearest to their: vigorous, against, fellows, decoders, episcopalian, huckleberries, themes, validly,
# Nearest to some: stupidity, systems, cruzi, lycanthropy, damnation, roth, collections, carducci,
# Nearest to two: five, zero, synth, four, hazards, georgia, maneuverability, d,
# Nearest to may: scan, schematic, defect, cleverly, eigenvalues, ambulances, bbc, leeson,
# Nearest to more: fascinating, initials, skimmed, retrofit, decorative, kinematics, rde, purchases,
# Nearest to prince: hireling, knights, bacchus, veiled, hellenism, letelier, kinase, distribute,
# Nearest to ocean: anatomically, cities, nobita, keto, reprised, jesuits, rooting, flowing,
# Nearest to versions: keep, framing, chanced, choose, lingual, stylistic, disciplined, it,
# Nearest to creation: outwardly, suicides, provide, koster, mysql, monies, imply, ringen,
# Nearest to institute: percy, bletchley, chiefs, frictions, london, sobel, brash, peripherals,
# Nearest to nobel: joyce, american, biologist, maxis, max, miss, poet, orchard,
# Nearest to police: advice, polynesia, radhakrishnan, milgrom, free, safin, residing, ditions,
# Nearest to consists: amtrak, urals, stalactites, starbuck, mountainous, thema, bernardi, elves,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4963 0.3894 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4895 0.4147 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4753 0.3906 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5152 0.3678 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4816 0.3520 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4662 0.3460 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4609 0.2923 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4349 0.2711 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4134 0.2731 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3956 0.2752 sec/batch
# Nearest to or: brightly, evade, daisy, branded, restarted, atm, hooks, faroes,
# Nearest to th: assimilated, valuing, purport, lisan, amen, calvinists, laughs, simmering,
# Nearest to but: purely, headset, antes, flocks, weld, trier, quintus, coating,
# Nearest to their: vigorous, against, rarely, anthropologists, fellows, episcopalian, themes, risk,
# Nearest to some: systems, stupidity, cruzi, damnation, collections, certifies, lycanthropy, carducci,
# Nearest to two: five, zero, synth, four, hazards, purchasing, maneuverability, georgia,
# Nearest to may: scan, schematic, ambulances, defect, dingane, cleverly, bbc, leeson,
# Nearest to more: fascinating, skimmed, initials, retrofit, decorative, purchases, provides, kinematics,
# Nearest to prince: hireling, knights, veiled, bacchus, letelier, hellenism, collectivity, entertainer,
# Nearest to ocean: cities, anatomically, keto, elevation, nobita, flowing, towns, dunbartonshire,
# Nearest to versions: framing, keep, chanced, choose, rtf, examine, stylistic, gigabytes,
# Nearest to creation: outwardly, suicides, provide, koster, mysql, cypriot, imply, faction,
# Nearest to institute: percy, bletchley, london, sobel, frictions, chiefs, graduate, brash,
# Nearest to nobel: joyce, biologist, maxis, max, american, miss, comedian, poet,
# Nearest to police: polynesia, advice, radhakrishnan, sophomore, verifiability, humanitarian, protest, safin,
# Nearest to consists: amtrak, stalactites, urals, starbuck, mansi, thema, mountainous, grenadian,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4065 0.2783 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4069 0.2720 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4290 0.2774 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3910 0.2735 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3802 0.2806 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4074 0.3239 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3738 0.2986 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3797 0.2711 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4156 0.2722 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3690 0.2720 sec/batch
# Nearest to or: evade, daisy, brightly, restarted, faroes, branded, hooks, atm,
# Nearest to th: assimilated, valuing, lisan, simmering, purport, calvinists, neander, culling,
# Nearest to but: trier, headset, antes, flocks, purely, weld, coating, amerikkka,
# Nearest to their: against, vigorous, episcopalian, anthropologists, themes, rarely, risk, validly,
# Nearest to some: systems, stupidity, cruzi, collections, refinement, damnation, certifies, lycanthropy,
# Nearest to two: five, zero, four, synth, one, submarine, maneuverability, purchasing,
# Nearest to may: scan, schematic, defect, ambulances, dingane, leeson, eigenvalues, cleverly,
# Nearest to more: skimmed, fascinating, retrofit, purchases, initials, decorative, kinematics, fingertips,
# Nearest to prince: hireling, knights, bacchus, veiled, guantanamo, collectivity, hellenism, claimants,
# Nearest to ocean: cities, elevation, anatomically, keto, flowing, subtropical, towns, coastal,
# Nearest to versions: framing, keep, chanced, licensed, rtf, xp, lingual, gigabytes,
# Nearest to creation: outwardly, suicides, koster, imply, faction, cypriot, provide, mysql,
# Nearest to institute: percy, bletchley, london, graduate, chiefs, sobel, frictions, brash,
# Nearest to nobel: joyce, american, maxis, biologist, max, miss, poet, comedian,
# Nearest to police: radhakrishnan, polynesia, advice, sophomore, humanitarian, protest, verifiability, certificate,
# Nearest to consists: amtrak, urals, stalactites, starbuck, thema, mountainous, mansi, facing,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3917 0.2742 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4007 0.2877 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3585 0.2900 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3540 0.3147 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3802 0.2842 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3574 0.2780 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3777 0.2816 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3856 0.3031 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3578 0.2815 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3376 0.2863 sec/batch
# Nearest to or: evade, daisy, branded, brightly, faroes, restarted, tipler, eliminated,
# Nearest to th: assimilated, valuing, simmering, lisan, purport, centuries, calvinists, preclude,
# Nearest to but: antes, trier, flocks, weld, purely, amerikkka, forgeries, assign,
# Nearest to their: against, vigorous, episcopalian, rarely, began, risk, themes, penises,
# Nearest to some: stupidity, cruzi, systems, lycanthropy, damnation, collections, certifies, cymbal,
# Nearest to two: five, zero, four, one, submarine, purchasing, six, maneuverability,
# Nearest to may: defect, scan, ambulances, schematic, dingane, cleverly, leeson, pes,
# Nearest to more: fingertips, retrofit, kinematics, work, initials, fascinating, purchases, olin,
# Nearest to prince: hireling, knights, bacchus, collectivity, veiled, guantanamo, compostela, claimants,
# Nearest to ocean: cities, anatomically, elevation, flowing, keto, subtropical, towns, salting,
# Nearest to versions: xp, framing, licensed, keep, rtf, databases, gigabytes, lingual,
# Nearest to creation: outwardly, suicides, cypriot, koster, faction, imply, provide, mysql,
# Nearest to institute: percy, bletchley, graduate, london, sobel, frictions, chiefs, peripherals,
# Nearest to nobel: joyce, biologist, maxis, american, max, miss, harwood, poet,
# Nearest to police: humanitarian, sophomore, radhakrishnan, protest, advice, verifiability, polynesia, sanctions,
# Nearest to consists: amtrak, stalactites, urals, starbuck, mansi, thema, mountainous, facing,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3168 0.2822 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3202 0.2815 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3760 0.2799 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3827 0.2808 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3763 0.2787 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3152 0.2818 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3038 0.2754 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3181 0.2806 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2223 0.2805 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2924 0.2772 sec/batch
# Nearest to or: evade, branded, faroes, brightly, daisy, restarted, tipler, eliminated,
# Nearest to th: assimilated, simmering, valuing, lisan, calvinists, purport, preclude, byzantine,
# Nearest to but: antes, flocks, headset, weld, trier, purely, rescind, role,
# Nearest to their: against, vigorous, episcopalian, huckleberries, began, racist, rarely, themes,
# Nearest to some: stupidity, cruzi, collections, systems, lycanthropy, cymbal, certifies, carducci,
# Nearest to two: five, zero, four, one, seven, six, nine, submarine,
# Nearest to may: defect, scan, dingane, schematic, pes, cleverly, ambulances, umlaut,
# Nearest to more: work, retrofit, fingertips, kinematics, olin, purchases, skimmed, initials,
# Nearest to prince: knights, hireling, hellenism, bacchus, anastasia, vladislav, collectivity, guantanamo,
# Nearest to ocean: cities, elevation, anatomically, flowing, keto, subtropical, salting, stalactites,
# Nearest to versions: xp, databases, framing, rtf, licensed, implementation, dos, lingual,
# Nearest to creation: outwardly, koster, provide, suicides, mysql, imply, cypriot, yoda,
# Nearest to institute: graduate, percy, bletchley, sobel, london, peripherals, chiefs, frictions,
# Nearest to nobel: joyce, biologist, american, max, maxis, poet, physiology, sociologist,
# Nearest to police: protest, humanitarian, sophomore, radhakrishnan, verifiability, advice, polynesia, safin,
# Nearest to consists: amtrak, stalactites, urals, mountainous, mansi, starbuck, thema, grenadian,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2828 0.2857 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2616 0.2781 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3459 0.1280 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2370 0.2797 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2172 0.2807 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1759 0.2796 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2381 0.2825 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2021 0.2787 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2052 0.2834 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1693 0.2808 sec/batch
# Nearest to or: evade, branded, faroes, daisy, brightly, restarted, tipler, unneeded,
# Nearest to th: assimilated, simmering, valuing, lisan, preclude, purport, calvinists, periods,
# Nearest to but: flocks, antes, weld, headset, boggy, trier, forgeries, rescind,
# Nearest to their: against, episcopalian, vigorous, huckleberries, began, racist, risk, rarely,
# Nearest to some: stupidity, cruzi, lycanthropy, systems, cymbal, certifies, untouched, collections,
# Nearest to two: five, zero, four, one, seven, submarine, six, nine,
# Nearest to may: defect, schematic, scan, dingane, nerve, extrapolation, reforestation, shrouded,
# Nearest to more: work, kinematics, fingertips, skimmed, sprites, retrofit, purchases, initials,
# Nearest to prince: hireling, knights, hellenism, bacchus, acquiesce, collectivity, vladislav, iv,
# Nearest to ocean: flowing, subtropical, cities, elevation, keto, anatomically, stalactites, dunbartonshire,
# Nearest to versions: xp, licensed, rtf, dos, commands, lingual, geek, implementation,
# Nearest to creation: outwardly, mysql, koster, provide, suicides, cypriot, organisers, ringen,
# Nearest to institute: graduate, bletchley, sobel, percy, london, peripherals, geology, chiefs,
# Nearest to nobel: biologist, joyce, maxis, max, american, physiology, mythologie, sociologist,
# Nearest to police: sophomore, verifiability, radhakrishnan, protest, humanitarian, advice, complicit, polynesia,
# Nearest to consists: amtrak, stalactites, urals, mountainous, easternmost, mansi, dams, starbuck,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2220 0.2812 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2096 0.2841 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2159 0.2778 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1128 0.2832 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1654 0.2792 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1401 0.2816 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1287 0.2761 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1756 0.2804 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2003 0.2772 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1532 0.2822 sec/batch
# Nearest to or: branded, evade, daisy, faroes, brightly, tipler, unneeded, restarted,
# Nearest to th: assimilated, simmering, preclude, valuing, lisan, calvinists, periods, purport,
# Nearest to but: flocks, antes, boggy, weld, headset, coating, assign, forgeries,
# Nearest to their: against, vigorous, episcopalian, risk, racist, anthropologists, rarely, huckleberries,
# Nearest to some: systems, stupidity, cruzi, refinement, idl, words, paleocene, pots,
# Nearest to two: zero, five, four, one, seven, six, submarine, three,
# Nearest to may: defect, schematic, scan, nerve, extrapolation, dingane, glycerol, bodily,
# Nearest to more: kinematics, work, sprites, skimmed, fingertips, retrofit, decorative, purchases,
# Nearest to prince: knights, hireling, hellenism, bacchus, acquiesce, collectivity, compostela, letelier,
# Nearest to ocean: subtropical, keto, anatomically, cities, flowing, elevation, stalactites, nobita,
# Nearest to versions: xp, rtf, licensed, dos, commands, reset, lingual, geek,
# Nearest to creation: outwardly, mysql, koster, permeated, postulated, materialism, provide, goo,
# Nearest to institute: graduate, london, bletchley, sobel, percy, education, peripherals, faculty,
# Nearest to nobel: joyce, biologist, maxis, max, physiology, mythologie, american, harwood,
# Nearest to police: sophomore, humanitarian, verifiability, radhakrishnan, advice, protest, complicit, enforcement,
# Nearest to consists: amtrak, stalactites, urals, mountainous, starbuck, facing, thema, mansi,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1396 0.2833 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1768 0.2796 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1618 0.2844 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1323 0.2773 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1693 0.2804 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1793 0.2773 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2000 0.2792 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1329 0.2794 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1266 0.2806 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1629 0.2765 sec/batch
# Nearest to or: branded, evade, daisy, tipler, brightly, atm, zealotry, restarted,
# Nearest to th: assimilated, preclude, valuing, simmering, calvinists, lisan, centuries, culling,
# Nearest to but: flocks, antes, weld, distributist, headset, forgeries, putting, assign,
# Nearest to their: against, episcopalian, vigorous, risk, rarely, penises, racist, began,
# Nearest to some: stupidity, cruzi, rifts, refinement, systems, cymbal, lycanthropy, pots,
# Nearest to two: zero, five, four, one, seven, six, three, nine,
# Nearest to may: defect, scan, schematic, shrouded, dingane, extrapolation, amending, umlaut,
# Nearest to more: work, kinematics, sprites, retrofit, decorative, skimmed, fingertips, rigging,
# Nearest to prince: knights, hireling, hellenism, acquiesce, anastasia, bacchus, empress, letelier,
# Nearest to ocean: keto, anatomically, subtropical, stations, station, stalactites, dunbartonshire, flowing,
# Nearest to versions: xp, commands, licensed, dos, rtf, gigabytes, geek, lingual,
# Nearest to creation: outwardly, mysql, permeated, postulated, koster, materialism, imply, suicides,
# Nearest to institute: graduate, bletchley, london, sobel, percy, faculty, education, peripherals,
# Nearest to nobel: biologist, joyce, maxis, american, physiology, max, prize, mythologie,
# Nearest to police: humanitarian, sophomore, advice, verifiability, protest, enforcement, radhakrishnan, complicit,
# Nearest to consists: amtrak, stalactites, urals, facing, mountainous, easternmost, agilent, cavalcanti,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2039 0.2855 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1583 0.2800 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1858 0.2776 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1838 0.2799 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1218 0.2787 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0928 0.2825 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1407 0.2793 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1340 0.2825 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1566 0.2772 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2115 0.2807 sec/batch
# Nearest to or: branded, evade, daisy, privileges, faroes, disciplinary, tipler, disparage,
# Nearest to th: assimilated, simmering, valuing, centuries, preclude, calvinists, lisan, culling,
# Nearest to but: flocks, distributist, antes, trier, headset, weld, putting, quintus,
# Nearest to their: against, episcopalian, vigorous, penises, began, validly, racist, huckleberries,
# Nearest to some: stupidity, cruzi, rifts, halberd, cymbal, systems, pots, certifies,
# Nearest to two: five, zero, four, one, seven, six, nine, three,
# Nearest to may: defect, dingane, amending, pes, jurisdictions, reforestation, shrouded, bbc,
# Nearest to more: work, kinematics, retrofit, sprites, municipal, skimmed, olin, fingertips,
# Nearest to prince: knights, hireling, hellenism, anastasia, bacchus, acquiesce, empress, lln,
# Nearest to ocean: anatomically, keto, subtropical, dependencies, station, stations, nobita, dunbartonshire,
# Nearest to versions: xp, commands, rtf, dos, licensed, geek, lingual, gigabytes,
# Nearest to creation: mysql, outwardly, materialism, provide, permeated, suicides, koster, postulated,
# Nearest to institute: graduate, london, bletchley, sobel, faculty, percy, geology, harvard,
# Nearest to nobel: joyce, biologist, american, prize, physiology, maxis, max, mythologie,
# Nearest to police: humanitarian, verifiability, enforcement, advice, sophomore, protest, radhakrishnan, complicit,
# Nearest to consists: stalactites, amtrak, urals, mountainous, dams, agilent, facing, mansi,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2022 0.2805 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1226 0.2820 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1125 0.2795 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1157 0.2803 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0153 0.2808 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1129 0.2795 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1227 0.2812 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0944 0.2777 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1960 0.0538 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1083 0.2799 sec/batch
# Nearest to or: branded, evade, daisy, tipler, restarted, privileges, eliminated, unneeded,
# Nearest to th: assimilated, simmering, centuries, preclude, valuing, calvinists, lisan, byzantine,
# Nearest to but: headset, flocks, antes, weld, distributist, putting, rescind, indestructible,
# Nearest to their: against, episcopalian, began, vigorous, unheard, cavaliers, risk, sewerage,
# Nearest to some: cruzi, stupidity, systems, cymbal, halberd, lycanthropy, additives, pots,
# Nearest to two: zero, five, four, one, six, seven, nine, three,
# Nearest to may: defect, scan, bbc, schematic, shrouded, extrapolation, myasthenia, umlaut,
# Nearest to more: work, kinematics, skimmed, sprites, purchases, retrofit, bely, decorative,
# Nearest to prince: knights, hellenism, hireling, letelier, lln, empress, anastasia, bacchus,
# Nearest to ocean: anatomically, keto, stations, subtropical, nobita, dependencies, stalactites, station,
# Nearest to versions: xp, dos, licensed, commands, rtf, os, geek, gigabytes,
# Nearest to creation: mysql, outwardly, provide, materialism, koster, permeated, goo, oaau,
# Nearest to institute: graduate, faculty, bletchley, sobel, london, percy, education, harvard,
# Nearest to nobel: biologist, joyce, physiology, prize, american, max, maxis, mythologie,
# Nearest to police: humanitarian, enforcement, protest, advice, verifiability, sophomore, radhakrishnan, safin,
# Nearest to consists: amtrak, stalactites, urals, mountainous, thema, dams, mansi, easternmost,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0653 0.2846 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0618 0.2780 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0561 0.2824 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0349 0.2766 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0407 0.2818 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9826 0.2782 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0286 0.2781 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0510 0.2801 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0895 0.2786 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0170 0.2800 sec/batch
# Nearest to or: branded, evade, daisy, romanizations, unneeded, certain, atm, disparage,
# Nearest to th: assimilated, preclude, centuries, simmering, valuing, lisan, byzantine, calvinists,
# Nearest to but: flocks, headset, antes, capella, quintus, coating, weld, indestructible,
# Nearest to their: episcopalian, against, carrion, began, vigorous, risk, cavaliers, unheard,
# Nearest to some: pots, cruzi, additives, systems, cymbal, flammable, stupidity, rifts,
# Nearest to two: five, zero, four, one, seven, three, nine, six,
# Nearest to may: defect, reforestation, bbc, nerve, keralites, myasthenia, scan, bondage,
# Nearest to more: work, skimmed, kinematics, sprites, retrofit, decorative, bely, purchases,
# Nearest to prince: knights, hellenism, hireling, letelier, anastasia, lln, bacchus, ecclesiae,
# Nearest to ocean: keto, anatomically, stations, station, nobita, subtropical, haq, dependencies,
# Nearest to versions: xp, rtf, licensed, commands, dos, lingual, geek, it,
# Nearest to creation: mysql, outwardly, materialism, provide, permeated, postulated, suicides, koster,
# Nearest to institute: graduate, faculty, london, sobel, bletchley, institutes, education, studying,
# Nearest to nobel: biologist, joyce, prize, physiology, biochemist, maxis, american, max,
# Nearest to police: enforcement, humanitarian, sophomore, verifiability, protest, radhakrishnan, complicit, advice,
# Nearest to consists: stalactites, amtrak, urals, mountainous, facing, thema, cavalcanti, dams,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9757 0.2809 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0353 0.2800 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9821 0.2767 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0138 0.2807 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0195 0.2807 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0142 0.2810 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0508 0.2780 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0914 0.2813 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0398 0.2813 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0096 0.2769 sec/batch
# Nearest to or: branded, evade, lexeme, certain, daisy, romanizations, disparage, words,
# Nearest to th: assimilated, preclude, centuries, simmering, playoffs, valuing, calvinists, lisan,
# Nearest to but: distributist, flocks, indestructible, headset, antes, coating, amerikkka, putting,
# Nearest to their: episcopalian, against, carrion, risk, validly, jerseys, rarely, vigorous,
# Nearest to some: systems, cruzi, stupidity, rifts, certifies, refinement, halberd, cymbal,
# Nearest to two: zero, five, four, one, three, seven, nine, six,
# Nearest to may: defect, nerve, pes, scan, myasthenia, bbc, paralleled, keralites,
# Nearest to more: work, skimmed, sprites, kinematics, bely, retrofit, decorative, rigging,
# Nearest to prince: knights, hellenism, hireling, letelier, lln, anastasia, acquiesce, gniezno,
# Nearest to ocean: keto, anatomically, stations, station, oujda, haq, nobita, intelsat,
# Nearest to versions: xp, commands, rtf, chanced, licensed, dos, geek, lingual,
# Nearest to creation: mysql, outwardly, materialism, permeated, tzimtzum, provide, flood, imply,
# Nearest to institute: graduate, faculty, institutes, london, sobel, bletchley, geology, fellows,
# Nearest to nobel: biologist, joyce, prize, physiology, american, biochemist, maxis, max,
# Nearest to police: enforcement, humanitarian, protest, verifiability, sophomore, advice, complicit, certificate,
# Nearest to consists: stalactites, urals, amtrak, agilent, disjoint, classes, illustrates, pythagorean,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0108 0.2852 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0660 0.2772 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0174 0.2833 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9962 0.2796 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0328 0.2811 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0559 0.2797 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0659 0.2811 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0249 0.2798 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0652 0.2771 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0476 0.2808 sec/batch
# Nearest to or: branded, evade, lexeme, romanizations, baptize, daisy, disparage, stomachs,
# Nearest to th: assimilated, centuries, preclude, valuing, byzantine, calvinists, simmering, lisan,
# Nearest to but: distributist, flocks, quintus, indestructible, thee, antes, amerikkka, trier,
# Nearest to their: episcopalian, against, validly, carrion, began, penises, risk, rarely,
# Nearest to some: cruzi, stupidity, rifts, refinement, systems, halberd, revel, pots,
# Nearest to two: zero, five, four, one, seven, three, nine, six,
# Nearest to may: defect, shrouded, scan, pes, bbc, umlaut, amending, nerve,
# Nearest to more: work, kinematics, skimmed, sprites, bely, retrofit, fingertips, decorative,
# Nearest to prince: hellenism, knights, hireling, empress, pressburg, aargau, gniezno, letelier,
# Nearest to ocean: anatomically, stations, keto, station, oujda, haq, nobita, dependencies,
# Nearest to versions: xp, rtf, commands, dos, gigabytes, licensed, geek, lingual,
# Nearest to creation: mysql, outwardly, materialism, flood, permeated, tzimtzum, imply, koster,
# Nearest to institute: graduate, faculty, institutes, sobel, london, bletchley, deutsche, fellows,
# Nearest to nobel: biologist, joyce, prize, physiology, american, max, biochemist, maxis,
# Nearest to police: enforcement, protest, humanitarian, complicit, polynesia, airbags, verifiability, sophomore,
# Nearest to consists: stalactites, urals, amtrak, facing, cavalcanti, frisia, instrumentals, mountainous,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0245 0.2792 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9958 0.2825 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0269 0.2782 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0576 0.2797 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0753 0.2786 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1003 0.2810 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1327 0.2799 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0235 0.2794 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9970 0.2772 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0320 0.2803 sec/batch
# Nearest to or: branded, romanizations, lexeme, words, evade, prefix, causative, daisy,
# Nearest to th: assimilated, centuries, calvinists, valuing, first, simmering, byzantine, playoffs,
# Nearest to but: headset, antes, indestructible, distributist, belgians, flocks, capella, amerikkka,
# Nearest to their: episcopalian, against, carrion, sewerage, validly, unheard, risk, racist,
# Nearest to some: cruzi, rifts, stupidity, systems, assertion, cymbal, pots, additives,
# Nearest to two: zero, five, four, one, three, seven, nine, six,
# Nearest to may: defect, pes, shrouded, myasthenia, scan, reforestation, umlaut, bbc,
# Nearest to more: work, sprites, bely, kinematics, skimmed, retrofit, increasingly, purchases,
# Nearest to prince: hellenism, knights, empress, hireling, letelier, lln, aargau, pressburg,
# Nearest to ocean: anatomically, keto, stations, oujda, station, haq, nobita, stalactites,
# Nearest to versions: xp, rtf, commands, dos, licensed, lingual, geek, gigabytes,
# Nearest to creation: mysql, materialism, outwardly, flood, permeated, provide, cybernetic, koster,
# Nearest to institute: graduate, faculty, sobel, bletchley, institutes, london, deutsche, percy,
# Nearest to nobel: biologist, prize, joyce, physiology, american, max, biochemist, mythologie,
# Nearest to police: enforcement, protest, polynesia, humanitarian, sophomore, airbags, safin, verifiability,
# Nearest to consists: stalactites, amtrak, urals, frisia, disjoint, instrumentals, are, facing,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9491 0.2827 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0133 0.2797 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0244 0.2809 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9915 0.2778 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0732 0.2811 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0092 0.2564 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9999 0.2816 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9786 0.2797 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9966 0.2808 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9429 0.2779 sec/batch
# Nearest to or: branded, romanizations, evade, causative, lexeme, daisy, certain, a,
# Nearest to th: assimilated, centuries, valuing, first, calvinists, simmering, playoffs, lisan,
# Nearest to but: headset, distributist, antes, indestructible, flocks, quintus, belgians, thee,
# Nearest to their: episcopalian, carrion, validly, jerseys, risk, sewerage, unheard, penises,
# Nearest to some: cruzi, pots, systems, stupidity, halberd, cymbal, rifts, heresiologists,
# Nearest to two: zero, five, four, one, three, seven, nine, six,
# Nearest to may: defect, scan, bbc, myasthenia, reforestation, shrouded, umlaut, bondage,
# Nearest to more: work, bely, skimmed, sprites, kinematics, purchases, retrofit, unconcerned,
# Nearest to prince: knights, hellenism, empress, letelier, hireling, lln, pressburg, gniezno,
# Nearest to ocean: anatomically, keto, haq, stations, oujda, nobita, station, siliceous,
# Nearest to versions: xp, rtf, licensed, dos, gigabytes, it, commands, geek,
# Nearest to creation: mysql, outwardly, flood, materialism, provide, cybernetic, koster, how,
# Nearest to institute: graduate, sobel, faculty, institutes, bletchley, deutsche, fellows, london,
# Nearest to nobel: prize, biologist, joyce, physiology, american, max, biochemist, medal,
# Nearest to police: enforcement, polynesia, sophomore, airbags, safin, protest, verifiability, complicit,
# Nearest to consists: stalactites, urals, amtrak, instrumentals, frisia, disjoint, agilent, are,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9757 0.2840 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9224 0.2772 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9888 0.2816 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9715 0.2774 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0051 0.2781 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9453 0.2807 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8981 0.2769 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9202 0.2849 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9203 0.2767 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9246 0.2894 sec/batch
# Nearest to or: branded, romanizations, a, to, certain, is, daisy, lexeme,
# Nearest to th: assimilated, centuries, first, playoffs, simmering, valuing, calvinists, preclude,
# Nearest to but: flocks, headset, indestructible, distributist, antes, capella, quintus, belgians,
# Nearest to their: carrion, episcopalian, teammates, jerseys, against, risk, sewerage, rarely,
# Nearest to some: systems, halberd, cruzi, pots, revel, rifts, celebritarian, heresiologists,
# Nearest to two: zero, five, four, one, three, seven, nine, six,
# Nearest to may: defect, scan, reforestation, bondage, myasthenia, lettuce, bodily, pes,
# Nearest to more: work, skimmed, sprites, bely, increasingly, purchases, fingertips, retrofit,
# Nearest to prince: knights, hellenism, empress, letelier, hireling, gniezno, lln, wasp,
# Nearest to ocean: anatomically, keto, oujda, oceans, stations, siliceous, haq, station,
# Nearest to versions: rtf, xp, licensed, commands, gigabytes, geek, lingual, chanced,
# Nearest to creation: mysql, outwardly, flood, materialism, permeated, cybernetic, tzimtzum, provide,
# Nearest to institute: graduate, faculty, sobel, institutes, bletchley, deutsche, london, geology,
# Nearest to nobel: prize, biologist, joyce, physiology, biochemist, wollaston, mythologie, medal,
# Nearest to police: enforcement, polynesia, sophomore, protest, complicit, airbags, safin, humanitarian,
# Nearest to consists: stalactites, amtrak, urals, are, instrumentals, disjoint, agilent, illustrates,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9558 0.2813 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9517 0.2806 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9610 0.2777 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9893 0.2808 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0066 0.2818 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9169 0.2763 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9527 0.2793 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9733 0.2785 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9580 0.2814 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9659 0.2785 sec/batch
# Nearest to or: branded, romanizations, certain, a, lexeme, evade, is, secondo,
# Nearest to th: assimilated, centuries, first, calvinists, valuing, playoffs, lisan, simmering,
# Nearest to but: indestructible, headset, antes, capella, amerikkka, distributist, belgians, chthonic,
# Nearest to their: episcopalian, carrion, teammates, holders, neo, sewerage, rarely, validly,
# Nearest to some: revel, celebritarian, silberman, pots, halberd, cruzi, bunyan, rifts,
# Nearest to two: zero, five, four, one, three, nine, six, seven,
# Nearest to may: scan, defect, objector, pes, shrouded, diligent, myasthenia, bondage,
# Nearest to more: work, bely, skimmed, increasingly, sprites, than, nevertheless, unconcerned,
# Nearest to prince: hellenism, knights, empress, hireling, gniezno, letelier, lln, aargau,
# Nearest to ocean: anatomically, oujda, haq, keto, dependencies, stations, station, siliceous,
# Nearest to versions: xp, licensed, rtf, gigabytes, commands, geek, chanced, lingual,
# Nearest to creation: mysql, flood, materialism, outwardly, permeated, tzimtzum, cybernetic, creationism,
# Nearest to institute: graduate, sobel, faculty, institutes, bletchley, deutsche, geology, studying,
# Nearest to nobel: prize, biologist, joyce, physiology, american, biochemist, wollaston, emil,
# Nearest to police: enforcement, polynesia, sophomore, airbags, protest, humanitarian, safin, complicit,
# Nearest to consists: stalactites, urals, amtrak, disjoint, instrumentals, illustrates, cavalcanti, pythagorean,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9893 0.2828 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9576 0.2792 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9610 0.2816 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9902 0.2780 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0089 0.2805 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9805 0.2795 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9225 0.2797 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9305 0.2808 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9249 0.2786 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0382 0.2847 sec/batch
# Nearest to or: branded, romanizations, a, certain, to, lexeme, evade, is,
# Nearest to th: assimilated, centuries, calvinists, valuing, century, first, lisan, playoffs,
# Nearest to but: headset, belgians, indestructible, antes, distributist, babylonia, similar, quintus,
# Nearest to their: episcopalian, carrion, sewerage, holders, risk, validly, although, penises,
# Nearest to some: celebritarian, lutheranism, silberman, revel, halberd, rifts, pots, boac,
# Nearest to two: zero, five, four, one, nine, three, six, seven,
# Nearest to may: defect, amending, objector, renounced, reforestation, wiretaps, scan, hanbali,
# Nearest to more: work, increasingly, bely, than, skimmed, records, sprites, retrofit,
# Nearest to prince: hellenism, empress, knights, gniezno, hireling, lln, letelier, aargau,
# Nearest to ocean: oujda, anatomically, haq, keto, station, dependencies, svalbard, stations,
# Nearest to versions: rtf, xp, licensed, geek, dos, lingual, chanced, gigabytes,
# Nearest to creation: mysql, flood, materialism, cybernetic, outwardly, koster, geology, permeated,
# Nearest to institute: graduate, sobel, institutes, geology, faculty, deutsche, bletchley, studying,
# Nearest to nobel: prize, biologist, joyce, physiology, american, biochemist, wollaston, emil,
# ...
# Nearest to th: century, centuries, first, rd, playoffs, late, calvinists, propagandistic,
# Nearest to but: not, similar, indestructible, however, to, in, and, only,
# Nearest to their: they, with, carrion, them, episcopalian, to, the, even,
# Nearest to some: are, that, or, much, many, a, and, although,
# Nearest to two: zero, four, five, one, three, nine, six, eight,
# Nearest to may: be, that, objector, switching, reforestation, sportswriter, accessing, if,
# Nearest to more: than, are, increasingly, any, and, bely, three, in,
# Nearest to prince: knights, empress, gniezno, meter, hireling, hellenism, apcs, renderman,
# Nearest to ocean: oceans, oujda, tides, infinitely, whidbey, causality, narrows, keto,
# Nearest to versions: licensed, xp, lingual, chanced, version, barnabas, geek, lcs,
# Nearest to creation: flood, geology, creationism, materialism, moshiach, mysql, threats, tracey,
# Nearest to institute: graduate, institut, institutes, dubna, reappraisal, sobel, deutsche, studying,
# Nearest to nobel: prize, physiology, american, laureate, biologist, medal, joyce, recipient,
# Nearest to police: enforcement, airbags, analyzing, complicit, radhakrishnan, sophomore, dingo, lingerie,
# Nearest to consists: illustrates, structure, urals, consist, instrumentals, simonides, stalactites, dhlakama,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7952 0.3200 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8365 0.3171 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7833 0.3185 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8343 0.3163 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8192 0.3225 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8489 0.3175 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8258 0.3253 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8060 0.3214 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8650 0.3175 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8616 0.3174 sec/batch
# Nearest to or: a, to, certain, such, are, romanizations, and, is,
# Nearest to th: century, centuries, first, rd, propagandistic, late, playoffs, calvinists,
# Nearest to but: not, in, however, and, similar, to, indestructible, only,
# Nearest to their: they, episcopalian, carrion, them, with, dinners, though, having,
# Nearest to some: are, that, or, much, although, many, a, halberd,
# Nearest to two: zero, four, five, one, three, nine, six, eight,
# Nearest to may: objector, be, that, reforestation, occur, sportswriter, little, switching,
# Nearest to more: than, are, and, in, increasingly, any, bely, over,
# Nearest to prince: empress, knights, caliph, gniezno, meter, hellenism, hireling, renderman,
# Nearest to ocean: oceans, oujda, atlantic, whidbey, infinitely, intelsat, causality, tropospheric,
# Nearest to versions: xp, licensed, lingual, chanced, barnabas, version, geek, hammadi,
# Nearest to creation: moshiach, flood, materialism, geology, creationism, tracey, threats, sutta,
# Nearest to institute: graduate, institut, institutes, dubna, reappraisal, sobel, deutsche, aerobatics,
# Nearest to nobel: prize, biologist, physiology, american, medal, joyce, laureates, notoc,
# Nearest to police: enforcement, airbags, personnel, analyzing, suspects, lingerie, complicit, dingo,
# Nearest to consists: illustrates, consist, urals, structure, instrumentals, stalactites, simonides, exercise,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8391 0.3212 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8076 0.3174 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8092 0.3444 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7576 0.3309 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8705 0.2830 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8422 0.3328 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9509 0.3615 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8690 0.3383 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8659 0.3172 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7730 0.3158 sec/batch
# Nearest to or: a, to, such, are, is, romanizations, certain, and,
# Nearest to th: century, centuries, first, late, propagandistic, rd, playoffs, calvinists,
# Nearest to but: to, however, not, in, and, similar, only, indestructible,
# Nearest to their: they, them, episcopalian, reluctant, with, to, who, carrion,
# Nearest to some: are, that, or, many, although, much, a, today,
# Nearest to two: zero, four, five, one, three, nine, six, eight,
# Nearest to may: be, sportswriter, objector, that, september, switching, occur, dates,
# Nearest to more: than, are, increasingly, and, bely, in, three, less,
# Nearest to prince: empress, knights, caliph, meter, gniezno, hereby, renderman, glencoe,
# Nearest to ocean: oujda, oceans, atlantic, intelsat, infinitely, submarine, whidbey, dependencies,
# Nearest to versions: xp, lingual, licensed, chanced, barnabas, version, rendering, geek,
# Nearest to creation: moshiach, materialism, creationism, flood, tracey, threats, geology, sutta,
# Nearest to institute: graduate, institut, reappraisal, sobel, dubna, institutes, aerobatics, deutsche,
# Nearest to nobel: prize, physiology, biologist, american, laureate, recipient, joyce, petrie,
# Nearest to police: enforcement, airbags, personnel, analyzing, suspects, radhakrishnan, complicit, polynesia,
# Nearest to consists: consist, illustrates, instrumentals, are, urals, stalactites, simonides, exercise,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7272 0.3202 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8173 0.3157 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7368 0.3166 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8402 0.3216 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7944 0.3168 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8309 0.3145 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8630 0.1803 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8075 0.3154 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8021 0.3167 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8004 0.3171 sec/batch
# Nearest to or: such, a, to, and, certain, are, is, romanizations,
# Nearest to th: century, centuries, propagandistic, first, late, rd, cosmogony, lisan,
# Nearest to but: not, however, and, to, in, indestructible, similar, only,
# Nearest to their: they, them, carrion, episcopalian, reluctant, with, to, dinners,
# Nearest to some: many, are, much, or, that, as, although, a,
# Nearest to two: zero, five, one, four, three, six, nine, eight,
# Nearest to may: occur, be, sportswriter, thunderstorms, september, reforestation, dates, five,
# Nearest to more: than, are, less, increasingly, bely, and, any, in,
# Nearest to prince: empress, knights, gniezno, caliph, hereby, meter, glencoe, vladislav,
# Nearest to ocean: oceans, oujda, atlantic, submarine, intelsat, tropospheric, heyerdahl, whidbey,
# Nearest to versions: xp, licensed, lingual, version, chanced, barnabas, rtf, dos,
# Nearest to creation: materialism, moshiach, mysql, creationism, flood, tracey, threats, sutta,
# Nearest to institute: graduate, institut, reappraisal, institutes, dubna, sobel, aerobatics, deutsche,
# Nearest to nobel: prize, american, physiology, laureate, biologist, recipient, joyce, petrie,
# Nearest to police: enforcement, airbags, suspects, radhakrishnan, analyzing, personnel, complicit, dingo,
# Nearest to consists: illustrates, consist, instrumentals, are, urals, simonides, mansi, structure,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7997 0.3201 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7989 0.3141 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7977 0.3163 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7574 0.3183 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7873 0.3168 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7771 0.3161 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8639 0.3147 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7294 0.3140 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7929 0.3143 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7610 0.3149 sec/batch
# Nearest to or: a, to, are, such, and, is, certain, some,
# Nearest to th: century, centuries, first, late, rd, propagandistic, calvinists, lisan,
# Nearest to but: not, and, in, however, similar, only, to, being,
# Nearest to their: they, them, with, carrion, to, make, who, episcopalian,
# Nearest to some: are, many, or, much, that, although, it, a,
# Nearest to two: zero, one, five, four, three, six, nine, seven,
# Nearest to may: be, occur, that, objector, september, sportswriter, dates, reforestation,
# Nearest to more: than, are, in, less, and, increasingly, bely, as,
# Nearest to prince: knights, empress, caliph, gniezno, meter, renderman, hereby, hudson,
# Nearest to ocean: oceans, oujda, submarine, intelsat, atlantic, tropospheric, dependencies, heyerdahl,
# Nearest to versions: licensed, xp, lingual, chanced, version, rendering, barnabas, modifications,
# Nearest to creation: moshiach, creationism, materialism, flood, threats, sutta, geology, mysql,
# Nearest to institute: institut, graduate, reappraisal, institutes, dubna, studying, aerobatics, sobel,
# Nearest to nobel: prize, laureate, physiology, biologist, recipient, joyce, laureates, petrie,
# Nearest to police: enforcement, airbags, mayhem, suspects, complicit, radhakrishnan, dingo, personnel,
# Nearest to consists: illustrates, are, consist, structure, encompasses, instrumentals, and, simonides,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7155 0.3201 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7927 0.3171 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8173 0.3181 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7936 0.3168 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7977 0.3255 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8707 0.3164 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8287 0.3146 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7635 0.3141 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7768 0.3162 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7990 0.3175 sec/batch
# Nearest to or: to, a, such, are, and, certain, some, of,
# Nearest to th: century, centuries, first, rd, late, calvinists, propagandistic, charlize,
# Nearest to but: not, and, in, however, only, similar, to, few,
# Nearest to their: they, them, to, carrion, episcopalian, with, own, make,
# Nearest to some: are, many, that, or, much, although, and, though,
# Nearest to two: zero, one, four, five, three, six, nine, eight,
# Nearest to may: be, that, occur, sportswriter, objector, duration, five, dates,
# Nearest to more: than, are, less, bely, increasingly, and, three, any,
# Nearest to prince: empress, knights, caliph, daigo, hereby, gniezno, renderman, hellenism,
# Nearest to ocean: intelsat, oceans, oujda, atlantic, submarine, tropospheric, whidbey, heyerdahl,
# Nearest to versions: xp, licensed, chanced, lingual, version, rendering, barnabas, geek,
# Nearest to creation: flood, creationism, geology, materialism, moshiach, sutta, mysql, tracey,
# Nearest to institute: graduate, institut, reappraisal, institutes, dubna, technology, studying, sobel,
# Nearest to nobel: prize, laureate, physiology, american, recipient, biologist, physics, petrie,
# Nearest to police: enforcement, airbags, personnel, suspects, radhakrishnan, dingo, mayhem, officers,
# Nearest to consists: illustrates, consist, are, simonides, urals, encompasses, disjoint, enables,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8258 0.3200 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7995 0.3154 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7739 0.3168 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7969 0.3242 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8255 0.3132 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8229 0.3160 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8021 0.3194 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8070 0.3004 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7601 0.2707 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7674 0.2716 sec/batch
# Nearest to or: to, a, such, are, and, is, certain, some,
# Nearest to th: century, centuries, first, rd, late, propagandistic, of, eventual,
# Nearest to but: not, in, and, however, similar, to, a, only,
# Nearest to their: they, them, with, to, carrion, having, own, other,
# Nearest to some: are, or, many, that, to, much, a, although,
# Nearest to two: zero, one, five, four, three, six, nine, eight,
# Nearest to may: be, that, occur, sportswriter, five, duration, dates, objector,
# Nearest to more: than, are, and, in, less, three, as, increasingly,
# Nearest to prince: empress, knights, renderman, gniezno, daigo, caliph, hereby, hireling,
# Nearest to ocean: atlantic, oceans, intelsat, submarine, tropospheric, oujda, indian, station,
# Nearest to versions: xp, licensed, lingual, chanced, version, modifications, dos, rendering,
# Nearest to creation: flood, moshiach, materialism, creationism, threats, geology, mysql, sutta,
# Nearest to institute: institut, reappraisal, graduate, institutes, dubna, deutsche, sobel, studying,
# Nearest to nobel: prize, physiology, laureate, recipient, biologist, american, laureates, recipients,
# Nearest to police: enforcement, airbags, personnel, suspects, radhakrishnan, officers, complicit, mayhem,
# Nearest to consists: illustrates, consist, its, are, exercise, urals, disjoint, typically,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8192 0.3236 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8099 0.3193 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8931 0.3162 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8924 0.3225 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8382 0.3255 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8210 0.3168 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7043 0.3158 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7781 0.3157 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7030 0.3035 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8233 0.2788 sec/batch
# Nearest to or: to, such, a, is, are, and, some, certain,
# Nearest to th: century, centuries, first, rd, propagandistic, late, of, lisan,
# Nearest to but: however, and, in, not, to, similar, few, only,
# Nearest to their: them, to, they, with, make, own, reluctant, carrion,
# Nearest to some: are, many, or, much, that, to, although, not,
# Nearest to two: zero, four, five, one, three, six, nine, eight,
# Nearest to may: be, dates, duration, five, sportswriter, that, occur, september,
# Nearest to more: than, are, and, in, less, increasingly, bely, most,
# Nearest to prince: knights, renderman, empress, hereby, daigo, caliph, panther, glencoe,
# Nearest to ocean: submarine, oceans, oujda, intelsat, heyerdahl, tropospheric, atlantic, causality,
# Nearest to versions: xp, licensed, lingual, version, chanced, modifications, rendering, geek,
# Nearest to creation: materialism, moshiach, flood, creationism, mysql, tracey, sutta, threats,
# Nearest to institute: institut, graduate, reappraisal, institutes, dubna, technology, sobel, studying,
# Nearest to nobel: prize, physiology, recipient, biologist, american, laureate, recipients, laureates,
# Nearest to police: enforcement, airbags, personnel, department, officers, radhakrishnan, suspects, dingo,
# Nearest to consists: illustrates, consist, encompasses, mansi, exercise, are, the, simonides,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7714 0.2819 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7699 0.2746 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
